# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("data.csv")

# %%
df.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       501 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
#check missing values
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         5
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df = df.interpolate()

# %%
#EDA
#Correlation
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219170  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.310115 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.396372  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.090711  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.305148  0.731470
# RM      -0.219170  0.310115 -0.396372  0.090711 -0.305148  1.000000 -0.241924
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.241924  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.204123 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.210808  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.293610  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355334  0.261515
# ...

# %%
import seaborn as sns

# %%
plt.scatter(df['CRIM'],df['MEDV'])

# %%
import seaborn as sns
sns.regplot(x="RM", y="MEDV",data=df)
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %%
#Independent and dependent features
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
#TrainTestSplit
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 5     0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222
# 116   0.13158   0.0  10.01     0  0.547  6.176  72.5  2.7301    6  432
# 45    0.17142   0.0   6.91     0  0.448  5.682  33.8  5.1004    3  233
# 16    1.05393   0.0   8.14     0  0.538  5.935  29.3  4.4986    4  307
# 468  15.57570   0.0  18.10     0  0.580  5.926  71.0  2.9084   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 106   0.17120   0.0   8.56     0  0.520  5.836  91.9  2.2110    5  384
# 270   0.29916  20.0   6.96     0  0.464  5.856  42.1  4.4290    3  223
# 348   0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 435  11.16040   0.0  18.10     0  0.740  6.629  94.6  2.1247   24  666
# 102   0.22876   0.0   8.56     0  0.520  6.405  85.4  2.7147    5  384
#
#      PTRATIO       B  LSTAT
# 5       18.7  394.12   5.21
# 116     17.8  393.30  12.04
# ...

# %%
x_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 173  0.09178   0.0   4.05     0  0.510  6.416   84.1  2.6463    5  296
# 274  0.05644  40.0   6.41     1  0.447  6.758   32.9  4.0776    4  254
# 491  0.10574   0.0  27.74     0  0.609  5.983   98.8  1.8681    4  711
# 72   0.09164   0.0  10.81     0  0.413  6.065    7.8  5.2873    4  305
# 452  5.09017   0.0  18.10     0  0.713  6.297   91.8  2.3682   24  666
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 441  9.72418   0.0  18.10     0  0.740  6.406   97.2  2.0651   24  666
# 23   0.98843   0.0   8.14     0  0.538  5.813  100.0  4.0952    4  307
# 225  0.52693   0.0   6.20     0  0.504  8.725   83.0  2.8944    8  307
# 433  5.58107   0.0  18.10     0  0.713  6.436   87.9  2.3158   24  666
# 447  9.92485   0.0  18.10     0  0.740  6.251   96.6  2.1980   24  666
#
#      PTRATIO       B  LSTAT
# 173     16.6  395.50   9.04
# 274     17.6  396.90   3.53
# ...

# %%
#standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_test=scaler.transform(x_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
#model training
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Assumption

# %%
#print the coeffiecients and intercepts
print(regression.coef_)
# Out:
# [-1.11174047  0.83260856  0.38671062  0.81447136 -1.77807221  2.87799865
#  -0.27527583 -2.90578706  2.11776626 -1.48014405 -2.05620012  1.02523858
#  -3.91735937]

# %%
print(regression.intercept_)
# Out:
# 23.01581920903955

# %%
#prediction with test data
reg_pred=regression.predict(x_test)

# %%
reg_pred
# Out:
# array([28.59764722, 36.48025151, 15.42124783, 25.38727011, 18.86984156,
#        23.12569403, 17.38942938, 14.05869583, 23.05673371, 20.57092879,
#        24.84988361, 18.57876087, -6.85456425, 21.78116427, 19.24991581,
#        26.15267976, 20.37824684,  5.64962314, 40.39526964, 17.59743426,
#        27.42429068, 30.15637173, 10.9271749 , 23.9859625 , 18.11059679,
#        15.98166377, 23.11965703, 14.53686737, 22.34178437, 19.31227097,
#        22.14638728, 25.17116243, 25.25409835, 18.62904693, 16.62034082,
#        17.59979996, 30.90432611, 20.20102706, 23.89408739, 24.83161294,
#        13.91920082, 31.78425553, 42.53168927, 17.62524033, 26.94882534,
#        17.23686544, 13.80524594, 26.05850991, 20.32499284, 30.05627979,
#        21.36860389, 34.11934824, 15.57483497, 26.04161749, 39.24444792,
#        23.00844035, 18.98555349, 33.07294625, 24.79833974, 12.97182681,
#        22.76373417, 30.84063455, 31.57425796, 16.29208217, 21.12947964,
# ...

# %%
#plot a scatter plot for prediction
plt.scatter(y_test,reg_pred)

# %%
residuals=y_test-reg_pred

# %%
residuals
# Out:
# 173    -4.997647
# 274    -4.080252
# 491    -1.821248
# 72     -2.587270
# 452    -2.769842
#          ...
# 441    -0.303351
# 23      1.118464
# 225    10.176660
# 433    -2.383829
# 447    -5.710699
# Name: MEDV, Length: 152, dtype: float64

# %%
residuals = y_test-reg_pred

# %%
residuals
# Out:
# 173    -4.997647
# 274    -4.080252
# 491    -1.821248
# 72     -2.587270
# 452    -2.769842
#          ...
# 441    -0.303351
# 23      1.118464
# 225    10.176660
# 433    -2.383829
# 447    -5.710699
# Name: MEDV, Length: 152, dtype: float64

# %%
#plot this residuals
sns.displot(residuals, kind ="kde")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#scatter plot wrt predictions and residuals
plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 3.1622134278698515
# 21.515011132615456
# 4.638427657365743

# %% [markdown]
# # R squared and adjuste R square

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.7112586590498118

# %%
1-(1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.684058387800881

# %% [markdown]
# # New Data Prediction

# %%
df.iloc[0:1].iloc[:, :-1].to_numpy()
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#         4.980e+00]])

# %%
#transform new data
scaler.transform(df.iloc[0:1].iloc[:, :-1].to_numpy())
# Out:
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.41709233,  0.29216419, -1.27338003, -0.28154625, -0.16513629,
#          0.34449052, -0.13030059,  0.15267164, -0.97798895, -0.66777595,
#         -1.32142483,  0.42854113, -1.04769976]])

# %%
regression.predict(scaler.transform(df.iloc[0:1].iloc[:, :-1].to_numpy()))
# Out:
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([30.05627979])

# %% [markdown]
# # Deployment

# %%
import pickle

# Assuming 'regression' is your model
with open('regmodel.pkl', 'wb') as file:
    pickle.dump(regression, file)

# %%
pickled_model=pickle.load(open('regmodel.pkl','rb'))

# %%
pickled_model.predict(scaler.transform(df.iloc[0:1].iloc[:, :-1].to_numpy()))
# Out:
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([30.05627979])
